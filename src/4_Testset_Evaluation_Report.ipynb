# %% [markdown]
# ## Metrics Evaluation Notebook
# This Notebook has the reports for all the models based on the common independent testset.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report
from utils.evaluation_utils import plot_confusion_matrix

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Metrics: Logistic Regression

# %%
df = pd.read_csv("../data/outputs/testset_logistic_regression_output.csv")
labels = sorted(list(df.sentiment.unique()))
plot_confusion_matrix(df['sentiment'], df['lr_prediction'], labels)

# %%
print(classification_report(df['sentiment'],df['lr_prediction']))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.63      0.63      0.63       215
#      neutral       0.55      0.57      0.56       284
#     positive       0.68      0.66      0.67       258
#
#     accuracy                           0.62       757
#    macro avg       0.62      0.62      0.62       757
# weighted avg       0.62      0.62      0.62       757

# %% [markdown]
# ## Metrics: RandomForest

# %%
df = pd.read_csv("../data/outputs/testset_random_forest_output.csv")
labels = sorted(list(df.sentiment.unique()))
plot_confusion_matrix(df['sentiment'], df['rf_prediction'], labels)

# %%
print(classification_report(df['sentiment'],df['rf_prediction']))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.19      0.31       215
#      neutral       0.44      0.87      0.58       284
#     positive       0.74      0.44      0.55       258
#
#     accuracy                           0.53       757
#    macro avg       0.70      0.50      0.48       757
# weighted avg       0.68      0.53      0.50       757

# %% [markdown]
# ## Metrics: DistilBert

# %%
df = pd.read_csv("../data/outputs/testset_distilbert_output.csv")
labels = sorted(list(df.sentiment.unique()))
plot_confusion_matrix(df['sentiment'], df['distilbert_prediction'], labels)

# %%
print(classification_report(df['sentiment'],df['distilbert_prediction']))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.68      0.46      0.54       215
#      neutral       0.48      0.69      0.56       284
#     positive       0.68      0.54      0.60       258
#
#     accuracy                           0.57       757
#    macro avg       0.61      0.56      0.57       757
# weighted avg       0.60      0.57      0.57       757

# %% [markdown]
# ## Metrics: XLM Roberta

# %%
df = pd.read_csv("../data/outputs/testset_xlmroberta_output.csv")
labels = sorted(list(df.sentiment.unique()))
# df.head()
plot_confusion_matrix(df['sentiment'], df['xlmroberta_prediction'], labels)

# %%
print(classification_report(df['sentiment'],df['xlmroberta_prediction']))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.63      0.69      0.66       215
#      neutral       0.57      0.51      0.54       284
#     positive       0.66      0.69      0.67       258
#
#     accuracy                           0.62       757
#    macro avg       0.62      0.63      0.62       757
# weighted avg       0.62      0.62      0.62       757
